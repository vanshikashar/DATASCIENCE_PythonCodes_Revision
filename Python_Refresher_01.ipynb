# %%
# Variables, Data Types, and Typecasting
name = "Vanshika"
age = 25
is_student= True
print(name, age)
# Out:
# Vanshika 25

# %%
# typecasting

# str to int
x = int("10")

# int to str
y = str(25)

# float to int
z = int(3.9)

# list from string
lst = list("abc")

print(x, y, z, lst)
# Out:
# 10 25 3 ['a', 'b', 'c']

# %%
# string

name = "Alice"
greeting = 'Hello'

# multiline string

mess = """This is
a multiline
string."""

print(name, greeting, mess)
# Out:
# Alice Hello This is
# a multiline
# string.

# %%
# string indexing and slicing

text = "Python"
text[0]
text[-1] 
text[0:2] 
text[:3] 
text[3:]
# Out:
# 'hon'

# %%
# common string methods

a= "hello".upper()
b= " Hello ".strip()
c= "hello world".split()
d= "-".join(["2025", "04", "14"]) 
e= "python".find("th")

print(a, b, c, d, e)
# Out:
# HELLO Hello ['hello', 'world'] 2025-04-14 2

# %%
# string formatting

name = "Akansha"
age = 30
f"Hello, {name}. You are {age} years old."
# Out:
# 'Hello, Akansha. You are 30 years old.'

# %%
# Operators in python

a= 10
b= 20

print(a + b) 
print(a - b) 
print(a * b) 
print(a / b)
print(a // b) 
print(a % b) 
print(a ** b)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10
# 100000000000000000000

# %%
#Comparison operators

a=11
b=6

print(a == b) 
print(a != b )
print(a > b )
print(a < b)
print(a >= b )
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
# Logical operators

x= True
y= False

print(x and y )
print(x or y )
print(not x )
# Out:
# False
# True
# False

# %%
#Bitwise operators

a=5
b=3

print(a&b)
print(a|b)
# Out:
# 1
# 7

# %%
# Assignment operators

a=10

a = 5
print(a)
a+= 5
print(a)
a -= 5
print(a)
a *= 5 
print(a)
a /= 5 
print(a)
a //= 5
print(a)
a %= 5
print(a)
a **= 5
print(a)
# Out:
# 5
# 10
# 5
# 25
# 5.0
# 1.0
# 1.0
# 1.0

# %%
#Membership and identity operators

lst=[1,2,3]
x=2

print(x in lst) 
print(x not in lst) 

a=10
b=10

print(a is b) 
print(a is not b)
# Out:
# True
# False
# True
# False

# %%
# taking input from user

name = input("Enter your name")
print("Hello", name)
# Out:
# Enter your name Vanshika
# Hello Vanshika

# %%
# Type conversion

age= int(input("Enter your age"))
price= float(input("Enter the price of book"))
print(f"You are {age} year old")
print("The price of book is", price)
# Out:
# Enter your age 20
# Enter the price of book 200
# You are 20 year old
# The price of book is 200.0

# %%
# Operator precedence

result = 10 + 2 * 3 
print(result)
result = (10 + 2) * 3 
print(result)
result = 2 ** 3 ** 2 
print(result)
# Out:
# 16
# 36
# 512

# %%
# If statement

x = 10
if x > 5:
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
# If-else statement

x = 3
if x > 5:
    print("x is greater than 5")
else:
    print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
# If-elif-else statement

x = 5
if x > 10:
    print("x is greater than 10")
elif x > 5:
    print("x is greater than 5 but not more than 10")
elif x == 5:
    print("x is exactly 5")
else:
    print("x is less than 5")
# Out:
# x is exactly 5

# %%
# Example: Categorizing data

age = 25
if age < 18:
    category = "Minor"
elif age < 65:
    category = "Adult"
else:
    category = "Senior Citizen"
print("Category:", category)
# Out:
# Category: Adult

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Applying conditions on Pandas Dataframe

import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Score': [85, 40, 75]}
df = pd.DataFrame(data)

df['Result'] = df['Score'].apply(lambda x: 'Pass' if x >= 50 else 'Fail')
print(df)
# Out:
#       Name  Score Result
# 0    Alice     85   Pass
# 1      Bob     40   Fail
# 2  Charlie     75   Pass

# %%
# Match-case statements

def http_status(code):
    match code:
        case 200:
            return "OK"
        case 400:
            return "Bad request."
        case 404:
            return "Not Found."
        case 500:
            return "Internal Server Error."
        case _:
            return "Unknown Status."
            
print(http_status(200))
print(http_status(404))
# Out:
# OK
# Not Found

# %%
# Match case example

point= (3, 4)

match point:
    case(0,0):
        print("Origin")
    case(x,0):
        print(f"X-Axis at {x}")
    case(0,y):
        print(f"Y-Axis at {y}")
    case(x,y):
        print(f"Point at {x}, {y}")
# Out:
# Point at 3, 4

# %%
# String Formatting and F-Strings

# Using format()

name = "Alisa"
age = 24
print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is Alisa and I am 24 years old.

# %%
# Positional and Keyword Arguments

print("{0} is learning {1}".format("Alina", "Python")) 
print("{name} is learning {language}".format(name="Alina", language="Python"))
# Out:
# Alina is learning Python
# Alina is learning Python

# %%
# Using f-Strings

name = "Vanshika"
age = 21
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Vanshika and I am 21 years old.

# %%
# Expressions Inside f-Strings

a = 5
b = 10
print(f"Sum of {a} and {b} is {a + b}")
# Out:
# Sum of 5 and 10 is 15

# %%
# Formatting Numbers

pi = 3.14159
print(f"Pi rounded to 2 decimal places: {pi:.2f}")
# Out:
# Pi rounded to 2 decimal places: 3.14

# %%
# Padding and Alignment

print(f"{'Python':<10}") 
print(f"{'Python':>10}") 
print(f"{'Python':^10}")
# Out:
# Python
#     Python
#   Python

# %%
# Loops in Python

# 1. For Loop

fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
# Using range()

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# 2. While Loop

count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# 3. Loop Control Statements

for i in range(5):
    if i == 3:
        break 
    print(i)
# Out:
# 0
# 1
# 2

# %%
# List and List Methods

my_list= []
n= [1, 2, 3, 4, 5]
mixed_list= [1, "Hello", 3.14, True]

print(mixed_list)
# Out:
# [1, 'Hello', 3.14, True]

# %%
# Example

fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits) 
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry', 'orange']
